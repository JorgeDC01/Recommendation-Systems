# %% [markdown]
# # Filtrado basado en contenido

# %% [markdown]
# **Preprocesamiento de los datos**
# - Unión de las 3 tablas: reviews, users y bussinesses
# - Adición de columnas como ```elite_years``` y ```categories```.
#
# **Procesamiento de los textos de las reviews**
# - TF-IDF con ```max_features=5000``` y 1-gramas
# - Word2Vec con ```vector_size=100```.
#
# **Modelo**
# - Light GBM
# - LightGBM optimizado con RandomizedSearch
# - LightGBM optimizado con Optuna

# %%
pip install lightgbm --quiet

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from lightgbm import LGBMRegressor

# %%
df_users = pd.read_csv("../../usuarios.csv", sep=",", dtype={"elite": str})
#df_users["elite"] = df_users["elite"].apply(lambda x: list(map(int, str(x).split(","))) if pd.notnull(x) else [])

df_businesses = pd.read_csv("../../negocios.csv", sep=",")
df_train = pd.read_csv("../../train_reviews.csv", sep=",")
df_test = pd.read_csv("../../test_reviews.csv", sep=",")

# %%
import itertools

dfs = {'users': df_users, 'businesses': df_businesses, 'train': df_train, 'test': df_test}
columnas_comunes = {}

for (name1, df1), (name2, df2) in itertools.combinations(dfs.items(), 2):
    if (name1 == 'train' and name2 =='test') or (name1 == 'test' and name2 =='train'):
        continue
    comunes = set(df1.columns).intersection(df2.columns)
    if comunes:
        columnas_comunes[(name1, name2)] = sorted(comunes)
        print(f"Columnas comunes entre {name1} y {name2}: {sorted(comunes)}")
        for col in comunes:
            rename1, rename2 = name1, name2
            if name1 == 'train' or name1 == 'test':
                rename1 = 'reviews'
            elif name2 == 'train' or name2 == 'test':
                rename2 = 'reviews'
            if col[-3:]== '_id':
                continue
            dfs[name1] = dfs[name1].rename(columns={col: f'{col}_{rename1}'})
            dfs[name2] = dfs[name2].rename(columns={col: f'{col}_{rename2}'})
# Out:
# Columnas comunes entre users y businesses: ['name', 'review_count']
# Columnas comunes entre users y train: ['cool', 'funny', 'useful', 'user_id']
# Columnas comunes entre users y test: ['cool', 'funny', 'useful', 'user_id']
# Columnas comunes entre businesses y train: ['business_id', 'stars']
# Columnas comunes entre businesses y test: ['business_id']

# %%
df_users = dfs['users']
df_businesses = dfs['businesses']
df_train = dfs['train']
df_test = dfs['test']

# %%
df_train = df_train.merge(df_users, on="user_id", how="left")
df_train = df_train.merge(df_businesses, on="business_id", how="left")

df_test = df_test.merge(df_users, on="user_id", how="left")
df_test = df_test.merge(df_businesses, on="business_id", how="left")

# %%
text_col = "text"
target_col = "stars_reviews"
id_col = "review_id"

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer()
count.fit(df_train[text_col])
print(f"Vocabulario total: {len(count.vocabulary_)}")
# Out:
# Vocabulario total: 209368

# %%
X_train = df_train.drop(columns=[target_col])
y_train = df_train[target_col]

X_test = df_test.copy()

# %%
# TF-IDF del texto
tfidf = TfidfVectorizer(max_features=5000)

X_text_train = tfidf.fit_transform(X_train[text_col])
X_text_test = tfidf.transform(X_test[text_col])

# %%
print(type(X_text_train), type(X_text_train))
print(X_text_train.shape, X_text_test.shape)
print(type(X_train))
# Out:
# <class 'scipy.sparse._csr.csr_matrix'> <class 'scipy.sparse._csr.csr_matrix'>
# (967784, 5000) (414765, 5000)
# <class 'pandas.core.frame.DataFrame'>

# %%
# Modelo LightGBM
model = LGBMRegressor(n_estimators=100, learning_rate=0.1, max_depth=7)
model.fit(X_text_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 9.454706 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 869492
# [LightGBM] [Info] Number of data points in the train set: 967784, number of used features: 5000
# [LightGBM] [Info] Start training from score 3.759882
# LGBMRegressor(max_depth=7)

# %%
# Predicción
y_pred = model.predict(X_text_test)

# %%
df_submission = pd.DataFrame({
    "review_id": df_test[id_col],
    "stars": y_pred
})
df_submission.to_csv("predictions_contenido/submission_lightgbm.csv", index=False)

# %% [markdown]
# Resultado inicial del MAE: `0.6922`

# %%
from sklearn.impute import SimpleImputer
from scipy.sparse import hstack
from lightgbm import LGBMRegressor


cols_estructura = [
    'review_count_users', 'useful_users', 'funny_users', 'cool_users', 'fans',
    'average_stars', 'compliment_hot', 'compliment_more', 'compliment_profile',
    'compliment_cute', 'compliment_list', 'compliment_note', 'compliment_plain',
    'compliment_cool', 'compliment_funny', 'compliment_writer', 'compliment_photos',
    'stars_businesses', 'review_count_businesses', 'is_open',
    'useful_reviews', 'funny_reviews', 'cool_reviews',
    'review_month', 'review_weekday', 'text_len'
]

df_train['review_month'] = pd.to_datetime(df_train['date']).dt.month
df_train['review_weekday'] = pd.to_datetime(df_train['date']).dt.weekday

df_test['review_month'] = pd.to_datetime(df_test['date']).dt.month
df_test['review_weekday'] = pd.to_datetime(df_test['date']).dt.weekday

cols_estructura += ['review_month', 'review_weekday']

df_train['text_len'] = df_train['text'].apply(len)
df_test['text_len'] = df_test['text'].apply(len)
cols_estructura += ['text_len']

imputer = SimpleImputer(strategy='mean')

X_struct_train = imputer.fit_transform(df_train[cols_estructura])
X_struct_test = imputer.transform(df_test[cols_estructura])

X_train_final = hstack([X_text_train, X_struct_train])
X_test_final = hstack([X_text_test, X_struct_test])
y_train = df_train["stars_reviews"]

# %%
model = LGBMRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=10,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1
)

model.fit(X_train_final, y_train)


y_pred = model.predict(X_test_final)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 8.092455 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873741
# [LightGBM] [Info] Number of data points in the train set: 967784, number of used features: 5029
# [LightGBM] [Info] Start training from score 3.759882
# c:\Users\paula\anaconda3\envs\py311_env\Lib\site-packages\lightgbm\basic.py:1238: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning("Converting data to scipy sparse matrix.")

# %%
df_output = pd.DataFrame({
    "review_id": df_test["review_id"],
    "stars": y_pred
})

df_output.to_csv("predictions_contenido/prediction_tfidf_lightgbm_29cols.csv", index=False)

# %% [markdown]
# Al añadir estas columnas extra de información al modelo, el resultado baja a un `0.5385`

# %% [markdown]
# Ahora vamos a proceder a añadir una característica que indica los años que el usuario ha estado en el programa elite de yelp.

# %%
df_train["elite_years"] = df_train["elite"].fillna("").apply(lambda x: len(x.split(',')) if x else 0)
df_test["elite_years"] = df_test["elite"].fillna("").apply(lambda x: len(x.split(',')) if x else 0)

# %%
cols_estructura += ['elite_years']

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Vectorizar 'categories'
cat_vect = CountVectorizer(max_features=100, token_pattern='[^,]+')  # separa por coma
X_cat_train = cat_vect.fit_transform(df_train['categories'].fillna(''))
X_cat_test = cat_vect.transform(df_test['categories'].fillna(''))

# %%
# Imputar valores faltantes en las columnas estructuradas
imputer = SimpleImputer(strategy='mean')
X_struct_train = imputer.fit_transform(df_train[cols_estructura])
X_struct_test = imputer.transform(df_test[cols_estructura])

# Concatenar texto + columnas
X_train_final = hstack([X_text_train, X_struct_train])
X_test_final = hstack([X_text_test, X_struct_test])
y_train = df_train["stars_reviews"]

# %%
#Entrenar el modelo
model = LGBMRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=10,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1
)

model.fit(X_train_final, y_train)

# Predicción
y_pred = model.predict(X_test_final)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 8.922104 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873759
# [LightGBM] [Info] Number of data points in the train set: 967784, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.759882
# c:\Users\paula\anaconda3\envs\py311_env\Lib\site-packages\lightgbm\basic.py:1238: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning("Converting data to scipy sparse matrix.")

# %%
# Guardar las predicciones en un archivo CSV
df_output = pd.DataFrame({
    "review_id": df_test["review_id"],
    "stars": y_pred
})
df_output.to_csv("predictions_contenido/prediction_tfidf_lightgbm_elite+categories.csv", index=False)

# %% [markdown]
# Vamos a hacer un RandomizedSearch para optimizar los parámetros

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer, mean_absolute_error
import time

# %%
# Modelo base
model = LGBMRegressor(random_state=42, n_jobs=-1)

param_dist = {
    'n_estimators': [100, 300, 500],
    'learning_rate': [0.01, 0.03, 0.05, 0.1],
    'max_depth': [7, 10, 12],
    'num_leaves': [31, 64, 128],
    'subsample': [0.7, 0.8, 1.0],
    'colsample_bytree': [0.7, 0.8, 1.0]
}

mae_scorer = make_scorer(mean_absolute_error, greater_is_better=False)

search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_dist,
    n_iter=40,
    scoring=mae_scorer,
    cv=3,
    verbose=2,
    random_state=42
)

start = time.time()

search.fit(X_train_final, y_train)

end = time.time()
elapsed_hours = round((end - start) / 3600, 2)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.121050 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=10, n_estimators=300, num_leaves=31, subsample=1.0; total time= 3.4min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.796422 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=10, n_estimators=300, num_leaves=31, subsample=1.0; total time= 3.3min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.764699 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=10, n_estimators=300, num_leaves=31, subsample=1.0; total time= 3.1min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.835019 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=12, n_estimators=300, num_leaves=128, subsample=0.8; total time= 5.8min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.114071 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=12, n_estimators=300, num_leaves=128, subsample=0.8; total time= 5.8min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.790012 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=12, n_estimators=300, num_leaves=128, subsample=0.8; total time= 5.7min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.912079 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=10, n_estimators=500, num_leaves=31, subsample=0.7; total time= 4.2min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.749707 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=10, n_estimators=500, num_leaves=31, subsample=0.7; total time= 4.2min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.437883 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=10, n_estimators=500, num_leaves=31, subsample=0.7; total time= 4.2min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.878468 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=12, n_estimators=500, num_leaves=128, subsample=1.0; total time= 6.8min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.994822 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=12, n_estimators=500, num_leaves=128, subsample=1.0; total time= 6.7min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.805421 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=12, n_estimators=500, num_leaves=128, subsample=1.0; total time= 6.7min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.677180 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=12, n_estimators=500, num_leaves=64, subsample=1.0; total time= 4.5min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.956315 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=12, n_estimators=500, num_leaves=64, subsample=1.0; total time= 4.5min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.087500 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=12, n_estimators=500, num_leaves=64, subsample=1.0; total time= 4.4min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.843000 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, num_leaves=64, subsample=0.8; total time= 4.7min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.974496 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, num_leaves=64, subsample=0.8; total time= 4.7min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.152684 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, num_leaves=64, subsample=0.8; total time= 4.7min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.963838 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, num_leaves=128, subsample=0.8; total time= 1.6min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.952893 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, num_leaves=128, subsample=0.8; total time= 1.5min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.857381 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, num_leaves=128, subsample=0.8; total time= 1.5min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.033049 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=300, num_leaves=31, subsample=0.8; total time= 2.4min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.762627 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=300, num_leaves=31, subsample=0.8; total time= 2.4min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.686609 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=300, num_leaves=31, subsample=0.8; total time= 2.4min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.964821 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, n_estimators=500, num_leaves=64, subsample=0.8; total time= 4.6min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.841974 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, n_estimators=500, num_leaves=64, subsample=0.8; total time= 4.7min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.689942 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, n_estimators=500, num_leaves=64, subsample=0.8; total time= 4.6min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.711864 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=12, n_estimators=500, num_leaves=128, subsample=0.8; total time= 6.3min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.697869 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=12, n_estimators=500, num_leaves=128, subsample=0.8; total time= 6.3min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.695281 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=12, n_estimators=500, num_leaves=128, subsample=0.8; total time= 6.3min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.711918 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=12, n_estimators=300, num_leaves=64, subsample=1.0; total time= 3.6min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.854551 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=12, n_estimators=300, num_leaves=64, subsample=1.0; total time= 3.5min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.645780 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=12, n_estimators=300, num_leaves=64, subsample=1.0; total time= 3.5min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.718383 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=12, n_estimators=100, num_leaves=64, subsample=0.7; total time= 1.6min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.866363 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=12, n_estimators=100, num_leaves=64, subsample=0.7; total time= 1.6min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.654661 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=12, n_estimators=100, num_leaves=64, subsample=0.7; total time= 1.7min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.722365 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=12, n_estimators=300, num_leaves=128, subsample=1.0; total time= 4.9min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.806506 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=12, n_estimators=300, num_leaves=128, subsample=1.0; total time= 4.9min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.015753 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=12, n_estimators=300, num_leaves=128, subsample=1.0; total time= 4.9min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.965085 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=12, n_estimators=500, num_leaves=31, subsample=0.8; total time= 4.7min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.669300 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=12, n_estimators=500, num_leaves=31, subsample=0.8; total time= 4.7min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.720110 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=12, n_estimators=500, num_leaves=31, subsample=0.8; total time= 4.8min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.700346 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=12, n_estimators=300, num_leaves=64, subsample=0.7; total time= 4.9min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.689362 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=12, n_estimators=300, num_leaves=64, subsample=0.7; total time= 4.8min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.762185 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=12, n_estimators=300, num_leaves=64, subsample=0.7; total time= 4.9min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.679811 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=128, subsample=0.7; total time= 1.5min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.681264 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=128, subsample=0.7; total time= 1.5min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.748739 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=128, subsample=0.7; total time= 1.5min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.885103 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=12, n_estimators=500, num_leaves=31, subsample=0.7; total time= 5.6min
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=7, n_estimators=300, num_leaves=128, subsample=1.0; total time= 3.0min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.689583 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=10, n_estimators=100, num_leaves=64, subsample=1.0; total time= 1.4min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.887243 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=10, n_estimators=100, num_leaves=64, subsample=1.0; total time= 1.3min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.759826 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=10, n_estimators=100, num_leaves=64, subsample=1.0; total time= 1.4min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.950309 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=10, n_estimators=500, num_leaves=31, subsample=0.8; total time= 4.4min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.157434 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=10, n_estimators=500, num_leaves=31, subsample=0.8; total time= 4.4min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.660298 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=10, n_estimators=500, num_leaves=31, subsample=0.8; total time= 4.4min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 8.773107 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873759
# [LightGBM] [Info] Number of data points in the train set: 967784, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.759882

# %%
print(f"Tiempo total de búsqueda: {elapsed_hours} horas")
print("Mejores parámetros encontrados:")
for k, v in search.best_params_.items():
    print(f"{k}: {v}")
print(f"Mejor MAE (negativo): {search.best_score_}")
# Out:
# Tiempo total de búsqueda: 7.26 horas
# Mejores parámetros encontrados:
# subsample: 0.8
# num_leaves: 64
# n_estimators: 500
# max_depth: 12
# learning_rate: 0.1
# colsample_bytree: 1.0
# Mejor MAE (negativo): -0.49150960937576565

# %%
best_model = search.best_estimator_
best_model.fit(X_train_final, y_train)

# Predicción
y_pred = best_model.predict(X_test_final)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 10.133734 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873759
# [LightGBM] [Info] Number of data points in the train set: 967784, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.759882
# c:\Users\paula\anaconda3\envs\py311_env\Lib\site-packages\lightgbm\basic.py:1238: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning("Converting data to scipy sparse matrix.")

# %%
df_output = pd.DataFrame({
    "review_id": df_test["review_id"],
    "stars": y_pred
})
df_output.to_csv("predictions_contenido/prediction_tfidf_lightgbm_gridsearch.csv", index=False)

# %% [markdown]
# Obtenemos unos resultados de `0.4906`

# %% [markdown]
# Randomized Search (versión 2)

# %%
# Modelo base
model = LGBMRegressor(random_state=42, n_jobs=-1)

param_dist = {
    'n_estimators': [400, 500, 600],
    'learning_rate': [0.08, 0.1, 0.12],
    'max_depth': [10, 12, 14],
    'num_leaves': [48, 64, 80],
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.9, 1.0]
}

mae_scorer = make_scorer(mean_absolute_error, greater_is_better=False)

search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_dist,
    n_iter=20,
    scoring=mae_scorer,
    cv=3,
    verbose=2,
    random_state=42
)

start = time.time()

search.fit(X_train_final, y_train)

end = time.time()
elapsed_hours = round((end - start) / 3600, 2)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.876454 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=10, n_estimators=500, num_leaves=80, subsample=0.7; total time= 5.5min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 9.599111 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=10, n_estimators=500, num_leaves=80, subsample=0.7; total time= 5.4min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.927637 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=10, n_estimators=500, num_leaves=80, subsample=0.7; total time= 5.7min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 9.172206 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.08, max_depth=10, n_estimators=600, num_leaves=48, subsample=0.8; total time= 6.2min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 8.344943 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.08, max_depth=10, n_estimators=600, num_leaves=48, subsample=0.8; total time= 6.6min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 7.158206 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.08, max_depth=10, n_estimators=600, num_leaves=48, subsample=0.8; total time= 6.6min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 9.866854 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=10, n_estimators=600, num_leaves=80, subsample=0.9; total time= 6.8min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 9.186915 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=10, n_estimators=600, num_leaves=80, subsample=0.9; total time= 6.9min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 8.284905 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=10, n_estimators=600, num_leaves=80, subsample=0.9; total time= 7.5min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 9.759448 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=12, n_estimators=500, num_leaves=80, subsample=0.8; total time= 5.9min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 7.290570 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=12, n_estimators=500, num_leaves=80, subsample=0.8; total time= 6.5min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 11.516595 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=12, n_estimators=500, num_leaves=80, subsample=0.8; total time= 6.3min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.975697 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, n_estimators=500, num_leaves=64, subsample=0.8; total time= 5.5min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 7.058329 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, n_estimators=500, num_leaves=64, subsample=0.8; total time= 5.2min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.584246 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, n_estimators=500, num_leaves=64, subsample=0.8; total time= 5.3min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.451425 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=14, n_estimators=400, num_leaves=80, subsample=0.7; total time= 5.2min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.077198 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=14, n_estimators=400, num_leaves=80, subsample=0.7; total time= 4.7min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.204400 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=14, n_estimators=400, num_leaves=80, subsample=0.7; total time= 4.6min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.275762 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.9, learning_rate=0.12, max_depth=12, n_estimators=400, num_leaves=64, subsample=0.8; total time= 4.3min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.491239 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.9, learning_rate=0.12, max_depth=12, n_estimators=400, num_leaves=64, subsample=0.8; total time= 4.3min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 7.543145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.9, learning_rate=0.12, max_depth=12, n_estimators=400, num_leaves=64, subsample=0.8; total time= 4.3min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.097402 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.9, learning_rate=0.12, max_depth=14, n_estimators=500, num_leaves=48, subsample=0.7; total time= 4.9min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.136205 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.9, learning_rate=0.12, max_depth=14, n_estimators=500, num_leaves=48, subsample=0.7; total time= 4.8min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 7.054446 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.9, learning_rate=0.12, max_depth=14, n_estimators=500, num_leaves=48, subsample=0.7; total time= 4.8min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 7.329572 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=10, n_estimators=600, num_leaves=64, subsample=0.9; total time=10.0min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 7.068884 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=10, n_estimators=600, num_leaves=64, subsample=0.9; total time= 5.6min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.935646 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=10, n_estimators=600, num_leaves=64, subsample=0.9; total time= 6.1min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 7.084905 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.9, learning_rate=0.12, max_depth=14, n_estimators=500, num_leaves=64, subsample=0.8; total time= 5.6min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.566102 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.9, learning_rate=0.12, max_depth=14, n_estimators=500, num_leaves=64, subsample=0.8; total time= 5.5min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.267493 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.9, learning_rate=0.12, max_depth=14, n_estimators=500, num_leaves=64, subsample=0.8; total time= 5.3min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.199594 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.9, learning_rate=0.08, max_depth=10, n_estimators=500, num_leaves=48, subsample=0.7; total time= 4.5min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.301279 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.9, learning_rate=0.08, max_depth=10, n_estimators=500, num_leaves=48, subsample=0.7; total time= 4.6min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.256992 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.9, learning_rate=0.08, max_depth=10, n_estimators=500, num_leaves=48, subsample=0.7; total time= 4.5min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.270319 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.9, learning_rate=0.12, max_depth=10, n_estimators=500, num_leaves=64, subsample=0.9; total time= 4.4min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.447982 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.9, learning_rate=0.12, max_depth=10, n_estimators=500, num_leaves=64, subsample=0.9; total time= 4.5min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.346364 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.9, learning_rate=0.12, max_depth=10, n_estimators=500, num_leaves=64, subsample=0.9; total time= 4.4min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.178564 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=14, n_estimators=600, num_leaves=64, subsample=0.7; total time= 6.0min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.337130 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=14, n_estimators=600, num_leaves=64, subsample=0.7; total time= 5.9min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.400783 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=14, n_estimators=600, num_leaves=64, subsample=0.7; total time= 5.9min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.466967 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=10, n_estimators=400, num_leaves=48, subsample=0.8; total time= 3.7min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.477891 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=10, n_estimators=400, num_leaves=48, subsample=0.8; total time= 3.7min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 6.145234 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=10, n_estimators=400, num_leaves=48, subsample=0.8; total time= 3.7min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.722729 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=14, n_estimators=500, num_leaves=64, subsample=0.8; total time= 5.3min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.322702 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=14, n_estimators=500, num_leaves=64, subsample=0.8; total time= 5.4min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 9.192946 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=14, n_estimators=500, num_leaves=64, subsample=0.8; total time=39.1min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 7.610658 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=10, n_estimators=600, num_leaves=80, subsample=0.7; total time= 6.2min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.654198 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=10, n_estimators=600, num_leaves=80, subsample=0.7; total time= 5.5min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.278256 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END colsample_bytree=1.0, learning_rate=0.12, max_depth=10, n_estimators=600, num_leaves=80, subsample=0.7; total time= 6.5min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 10.322740 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=10, n_estimators=400, num_leaves=64, subsample=0.7; total time= 4.9min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 10.491829 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=10, n_estimators=400, num_leaves=64, subsample=0.7; total time= 4.9min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 10.904192 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=10, n_estimators=400, num_leaves=64, subsample=0.7; total time= 4.8min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 8.909144 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.9, learning_rate=0.08, max_depth=12, n_estimators=400, num_leaves=64, subsample=0.7; total time= 4.6min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.869044 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.9, learning_rate=0.08, max_depth=12, n_estimators=400, num_leaves=64, subsample=0.7; total time= 4.2min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.377885 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.9, learning_rate=0.08, max_depth=12, n_estimators=400, num_leaves=64, subsample=0.7; total time= 4.2min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 5.849137 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=10, n_estimators=500, num_leaves=48, subsample=0.7; total time= 4.5min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.608553 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=10, n_estimators=500, num_leaves=48, subsample=0.7; total time= 4.2min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.190428 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=10, n_estimators=500, num_leaves=48, subsample=0.7; total time= 5.2min
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 8.969321 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 872595
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.761369
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=10, n_estimators=500, num_leaves=48, subsample=0.7; total time= 5.6min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 8.225883 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 872972
# [LightGBM] [Info] Number of data points in the train set: 645189, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.758269
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=10, n_estimators=500, num_leaves=48, subsample=0.7; total time= 4.6min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.153914 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873732
# [LightGBM] [Info] Number of data points in the train set: 645190, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.760009
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=10, n_estimators=500, num_leaves=48, subsample=0.7; total time= 4.2min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 9.655316 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873759
# [LightGBM] [Info] Number of data points in the train set: 967784, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.759882

# %%
print(f"\nTiempo total: {elapsed_hours} horas")
print("Mejores parámetros encontrados:")
for k, v in search.best_params_.items():
    print(f"{k}: {v}")
print(f"Mejor MAE (negativo): {search.best_score_}")
# Out:
# Tiempo total: 5.99 horas
# Mejores parámetros encontrados:
# subsample: 0.7
# num_leaves: 64
# n_estimators: 600
# max_depth: 14
# learning_rate: 0.12
# colsample_bytree: 1.0
# Mejor MAE (negativo): -0.4849501041408935

# %%
best_model = search.best_estimator_
best_model.fit(X_train_final, y_train)
y_pred = best_model.predict(X_test_final)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 12.390065 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 873759
# [LightGBM] [Info] Number of data points in the train set: 967784, number of used features: 5030
# [LightGBM] [Info] Start training from score 3.759882
# c:\Users\paula\anaconda3\envs\py311_env\Lib\site-packages\lightgbm\basic.py:1238: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning("Converting data to scipy sparse matrix.")

# %%
df_output = pd.DataFrame({
    "review_id": df_test["review_id"],
    "stars": y_pred
})
df_output.to_csv("predictions_contenido/prediction_tfidf_lightgbm_gridsearch2.csv", index=False)

# %% [markdown]
# Resultado: `0.4837`

# %% [markdown]
# Probamos a procesar el texto con word2vec en vez de tfidf

# %%
import nltk
import re
from gensim.models import Word2Vec
from scipy.sparse import hstack, csr_matrix
from tqdm import tqdm
from sklearn.impute import SimpleImputer

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\paula\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def tokenize(text):
    text = str(text).lower()
    text = re.sub(r"[^a-zA-Z\s]", "", text)  # quitar símbolos
    return nltk.word_tokenize(text)

df_train["tokens"] = df_train[text_col].fillna("").apply(tokenize)
df_test["tokens"] = df_test[text_col].fillna("").apply(tokenize)

# %%
all_tokens = df_train["tokens"].tolist() + df_test["tokens"].tolist()
w2v_model = Word2Vec(sentences=all_tokens, vector_size=100, window=5, min_count=2, workers=4, sg=1, seed=42)

# %%
# Promediar vectores por review

def get_review_vector(tokens, model, vector_size=100):
    vecs = [model.wv[word] for word in tokens if word in model.wv]
    if len(vecs) == 0:
        return np.zeros(vector_size)
    return np.mean(vecs, axis=0)

X_vec_train = np.vstack([get_review_vector(tokens, w2v_model, 100) for tokens in tqdm(df_train["tokens"])])
X_vec_test = np.vstack([get_review_vector(tokens, w2v_model, 100) for tokens in tqdm(df_test["tokens"])])

# Convertir a sparse
X_vec_train = csr_matrix(X_vec_train)
X_vec_test = csr_matrix(X_vec_test)
# Out:
# 100%|██████████| 967784/967784 [04:45<00:00, 3384.43it/s]
# 100%|██████████| 414765/414765 [02:20<00:00, 2960.24it/s]

# %%
# Añadir longitud del texto como feature

df_train["text_len"] = df_train[text_col].fillna("").apply(len)
df_test["text_len"] = df_test[text_col].fillna("").apply(len)

X_struct_train = df_train[["text_len"]].values
X_struct_test = df_test[["text_len"]].values

imputer = SimpleImputer(strategy="mean")
X_struct_train = imputer.fit_transform(X_struct_train)
X_struct_test = imputer.transform(X_struct_test)

X_struct_train = csr_matrix(X_struct_train)
X_struct_test = csr_matrix(X_struct_test)

# %%
# Añadir Word2Vec

X_train_final = hstack([X_vec_train, X_struct_train])
X_test_final = hstack([X_vec_test, X_struct_test])
y_train = df_train["stars_reviews"]

# %%
# Entrenar LightGBM

model = LGBMRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=10,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1
)
model.fit(X_train_final, y_train)

# Predicción
print("Generando predicciones...")
y_pred = model.predict(X_test_final)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.423514 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 25755
# [LightGBM] [Info] Number of data points in the train set: 967784, number of used features: 101
# [LightGBM] [Info] Start training from score 3.759882
# Generando predicciones...

# %%
# Guardar las predicciones en un archivo CSV
df_output = pd.DataFrame({
    "review_id": df_test["review_id"],
    "stars": y_pred
})
df_output.to_csv("predictions_contenido/prediction_word2vec_lightgbm.csv", index=False)

# %% [markdown]
# Ahora vamos a probar a mejorar con optuna

# %%
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from lightgbm import LGBMRegressor

# %%
# Dividir dataset
X_train_optuna, X_valid_optuna, y_train_optuna, y_valid_optuna = train_test_split(
    X_train_final, y_train, test_size=0.2, random_state=42
)

# %%
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
        "max_depth": trial.suggest_int("max_depth", 5, 15),
        "num_leaves": trial.suggest_int("num_leaves", 20, 128),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 10.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.0, 10.0),
        "random_state": 42,
        "n_jobs": -1
    }

    model = LGBMRegressor(**params)
    model.fit(X_train_optuna, y_train_optuna)
    preds = model.predict(X_valid_optuna)
    mae = mean_absolute_error(y_valid_optuna, preds)
    return mae

# %%
# Ejecutar optimización
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2025-04-24 03:18:37,729] A new study created in memory with name: no-name-45dc03ed-d656-461a-9539-bf6650fa5b22
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-04-24 03:24:12,542] Trial 0 finished with value: 0.4924679292489324 and parameters: {'n_estimators': 633, 'learning_rate': 0.197243382425006, 'max_depth': 9, 'num_leaves': 41, 'subsample': 0.9075642283992221, 'colsample_bytree': 0.7501553514091782, 'reg_alpha': 8.689173828201627, 'reg_lambda': 1.400309930031256}. Best is trial 0 with value: 0.4924679292489324.
# [I 2025-04-24 03:27:06,761] Trial 1 finished with value: 0.5521995352025133 and parameters: {'n_estimators': 146, 'learning_rate': 0.04571695682647693, 'max_depth': 13, 'num_leaves': 55, 'subsample': 0.7259636219293324, 'colsample_bytree': 0.7514157319705483, 'reg_alpha': 2.8574906900584516, 'reg_lambda': 3.6079084332883617}. Best is trial 0 with value: 0.4924679292489324.
# [I 2025-04-24 03:30:17,258] Trial 2 finished with value: 0.5013939566174803 and parameters: {'n_estimators': 193, 'learning_rate': 0.11217550903245539, 'max_depth': 12, 'num_leaves': 96, 'subsample': 0.8045275407693255, 'colsample_bytree': 0.9685953318028488, 'reg_alpha': 2.0788833771965223, 'reg_lambda': 6.222663592153083}. Best is trial 0 with value: 0.4924679292489324.
# [I 2025-04-24 03:36:06,063] Trial 3 finished with value: 0.5043163630642828 and parameters: {'n_estimators': 819, 'learning_rate': 0.10384439929755183, 'max_depth': 6, 'num_leaves': 73, 'subsample': 0.6130253721965395, 'colsample_bytree': 0.8226587559500335, 'reg_alpha': 1.220579916963529, 'reg_lambda': 6.270370691428803}. Best is trial 0 with value: 0.4924679292489324.
# [I 2025-04-24 03:39:06,053] Trial 4 finished with value: 0.7273667603957228 and parameters: {'n_estimators': 180, 'learning_rate': 0.01158132131180825, 'max_depth': 7, 'num_leaves': 82, 'subsample': 0.8145348755382454, 'colsample_bytree': 0.7155842624755382, 'reg_alpha': 2.275081997228522, 'reg_lambda': 1.1323205419967275}. Best is trial 0 with value: 0.4924679292489324.
# [I 2025-04-24 03:47:46,273] Trial 5 finished with value: 0.47986248803468584 and parameters: {'n_estimators': 971, 'learning_rate': 0.15500773294255307, 'max_depth': 12, 'num_leaves': 65, 'subsample': 0.9827773886710334, 'colsample_bytree': 0.8525559710936447, 'reg_alpha': 1.6883131590721856, 'reg_lambda': 3.842934144731902}. Best is trial 5 with value: 0.47986248803468584.
# [I 2025-04-24 03:50:55,801] Trial 6 finished with value: 0.5256954829237935 and parameters: {'n_estimators': 475, 'learning_rate': 0.17117831911796533, 'max_depth': 5, 'num_leaves': 20, 'subsample': 0.9072761202098433, 'colsample_bytree': 0.6181298904954325, 'reg_alpha': 5.432918329429817, 'reg_lambda': 4.4607867078113275}. Best is trial 5 with value: 0.47986248803468584.
# [I 2025-04-24 03:52:34,915] Trial 7 finished with value: 0.5488871771325867 and parameters: {'n_estimators': 112, 'learning_rate': 0.08739783538711923, 'max_depth': 8, 'num_leaves': 85, 'subsample': 0.9193002916023212, 'colsample_bytree': 0.7663533951683538, 'reg_alpha': 1.390181380439548, 'reg_lambda': 4.667504184002595}. Best is trial 5 with value: 0.47986248803468584.
# [I 2025-04-24 03:56:43,067] Trial 8 finished with value: 0.6362014406171871 and parameters: {'n_estimators': 241, 'learning_rate': 0.013311537058922374, 'max_depth': 8, 'num_leaves': 123, 'subsample': 0.8830291056898747, 'colsample_bytree': 0.7860207122367238, 'reg_alpha': 6.078441679170501, 'reg_lambda': 5.02146104970829}. Best is trial 5 with value: 0.47986248803468584.
# [I 2025-04-24 04:05:34,696] Trial 9 finished with value: 0.4782699877728843 and parameters: {'n_estimators': 797, 'learning_rate': 0.10075281636592523, 'max_depth': 13, 'num_leaves': 76, 'subsample': 0.7265212035127947, 'colsample_bytree': 0.7020743452585496, 'reg_alpha': 8.189629680067801, 'reg_lambda': 0.16246036190443514}. Best is trial 9 with value: 0.4782699877728843.
# [I 2025-04-24 04:16:13,478] Trial 10 finished with value: 0.4862552584144617 and parameters: {'n_estimators': 692, 'learning_rate': 0.04433642124953489, 'max_depth': 15, 'num_leaves': 125, 'subsample': 0.6841789134208492, 'colsample_bytree': 0.608641885630841, 'reg_alpha': 9.7703389690688, 'reg_lambda': 9.101547492717136}. Best is trial 9 with value: 0.4782699877728843.
# [I 2025-04-24 04:26:12,691] Trial 11 finished with value: 0.48874874430942716 and parameters: {'n_estimators': 968, 'learning_rate': 0.05416105296656285, 'max_depth': 11, 'num_leaves': 59, 'subsample': 0.7330669714260128, 'colsample_bytree': 0.900235063883388, 'reg_alpha': 7.295137802365224, 'reg_lambda': 0.23596049521889917}. Best is trial 9 with value: 0.4782699877728843.
# [I 2025-04-24 04:37:48,454] Trial 12 finished with value: 0.47376175241357 and parameters: {'n_estimators': 980, 'learning_rate': 0.07240230012212108, 'max_depth': 14, 'num_leaves': 100, 'subsample': 0.9851522997672368, 'colsample_bytree': 0.8640464138977856, 'reg_alpha': 3.506021374373825, 'reg_lambda': 2.670890915780755}. Best is trial 12 with value: 0.47376175241357.
# [I 2025-04-24 04:50:04,629] Trial 13 finished with value: 0.49380677363637265 and parameters: {'n_estimators': 815, 'learning_rate': 0.0264919049520703, 'max_depth': 15, 'num_leaves': 104, 'subsample': 0.643577695733546, 'colsample_bytree': 0.6876221114045675, 'reg_alpha': 3.852329510874684, 'reg_lambda': 2.319341906562446}. Best is trial 12 with value: 0.47376175241357.
# [I 2025-04-24 05:00:33,576] Trial 14 finished with value: 0.47601716064890104 and parameters: {'n_estimators': 835, 'learning_rate': 0.06981504340921439, 'max_depth': 14, 'num_leaves': 105, 'subsample': 0.7744949704965032, 'colsample_bytree': 0.908887107606631, 'reg_alpha': 4.147387372823947, 'reg_lambda': 2.3744367843290792}. Best is trial 12 with value: 0.47376175241357.
# [I 2025-04-24 05:06:21,201] Trial 15 finished with value: 0.4908525826964122 and parameters: {'n_estimators': 373, 'learning_rate': 0.06877954302065259, 'max_depth': 14, 'num_leaves': 107, 'subsample': 0.9976995224939877, 'colsample_bytree': 0.9665527129856322, 'reg_alpha': 4.000066190308435, 'reg_lambda': 2.476245599321248}. Best is trial 12 with value: 0.47376175241357.
# [I 2025-04-24 05:19:10,928] Trial 16 finished with value: 0.4997853175257216 and parameters: {'n_estimators': 997, 'learning_rate': 0.025505450661107692, 'max_depth': 10, 'num_leaves': 112, 'subsample': 0.847756434897471, 'colsample_bytree': 0.895058425761741, 'reg_alpha': 0.3480185963781146, 'reg_lambda': 2.476459457684868}. Best is trial 12 with value: 0.47376175241357.
# [I 2025-04-24 05:32:09,178] Trial 17 finished with value: 0.4929935737581922 and parameters: {'n_estimators': 877, 'learning_rate': 0.02660582864775396, 'max_depth': 14, 'num_leaves': 96, 'subsample': 0.7500294510517862, 'colsample_bytree': 0.9086570511740307, 'reg_alpha': 4.0900659571171305, 'reg_lambda': 6.205366038938729}. Best is trial 12 with value: 0.47376175241357.
# [I 2025-04-24 05:40:03,223] Trial 18 finished with value: 0.4866144873959452 and parameters: {'n_estimators': 704, 'learning_rate': 0.06592217743714672, 'max_depth': 11, 'num_leaves': 94, 'subsample': 0.773652421934375, 'colsample_bytree': 0.8509562057206306, 'reg_alpha': 6.50190076631873, 'reg_lambda': 8.904639310277368}. Best is trial 12 with value: 0.47376175241357.
# [I 2025-04-24 05:49:07,114] Trial 19 finished with value: 0.4941424454065437 and parameters: {'n_estimators': 553, 'learning_rate': 0.03642324857714462, 'max_depth': 14, 'num_leaves': 116, 'subsample': 0.9554487953999982, 'colsample_bytree': 0.995499201723274, 'reg_alpha': 4.7635950038234185, 'reg_lambda': 3.2098777887832757}. Best is trial 12 with value: 0.47376175241357.
# [I 2025-04-24 06:03:15,946] Trial 20 finished with value: 0.5067242774778954 and parameters: {'n_estimators': 897, 'learning_rate': 0.016998417575081973, 'max_depth': 13, 'num_leaves': 89, 'subsample': 0.8573491873809699, 'colsample_bytree': 0.948916294734413, 'reg_alpha': 3.0425327655019325, 'reg_lambda': 1.4211742944130523}. Best is trial 12 with value: 0.47376175241357.
# [I 2025-04-24 06:11:01,684] Trial 21 finished with value: 0.47945855650549907 and parameters: {'n_estimators': 780, 'learning_rate': 0.12097812584862155, 'max_depth': 13, 'num_leaves': 74, 'subsample': 0.6992999178689643, 'colsample_bytree': 0.6535447795054393, 'reg_alpha': 7.344690152881517, 'reg_lambda': 0.15850475266775366}. Best is trial 12 with value: 0.47376175241357.
# [I 2025-04-24 06:22:04,144] Trial 22 finished with value: 0.473636878287865 and parameters: {'n_estimators': 898, 'learning_rate': 0.0747496535968204, 'max_depth': 15, 'num_leaves': 100, 'subsample': 0.7688178855351352, 'colsample_bytree': 0.8562936878724577, 'reg_alpha': 4.974032294541474, 'reg_lambda': 1.277207802959523}. Best is trial 22 with value: 0.473636878287865.
# [I 2025-04-24 06:33:14,125] Trial 23 finished with value: 0.4734107359933434 and parameters: {'n_estimators': 898, 'learning_rate': 0.07378221675975216, 'max_depth': 15, 'num_leaves': 102, 'subsample': 0.7792008943813938, 'colsample_bytree': 0.8517078301428742, 'reg_alpha': 5.329709006223135, 'reg_lambda': 1.8359583206367602}. Best is trial 23 with value: 0.4734107359933434.
# [I 2025-04-24 06:44:26,530] Trial 24 finished with value: 0.47127563251180704 and parameters: {'n_estimators': 908, 'learning_rate': 0.08243018644694114, 'max_depth': 15, 'num_leaves': 115, 'subsample': 0.8312206912005538, 'colsample_bytree': 0.8357669904311911, 'reg_alpha': 5.432131697081831, 'reg_lambda': 1.1129696768063393}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 06:52:55,177] Trial 25 finished with value: 0.47355713429992013 and parameters: {'n_estimators': 729, 'learning_rate': 0.14304612477422451, 'max_depth': 15, 'num_leaves': 118, 'subsample': 0.8396422911701161, 'colsample_bytree': 0.8051629302530351, 'reg_alpha': 5.2630351169551375, 'reg_lambda': 1.025172993108853}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 07:01:18,292] Trial 26 finished with value: 0.4737546803225708 and parameters: {'n_estimators': 703, 'learning_rate': 0.1376735279449029, 'max_depth': 15, 'num_leaves': 118, 'subsample': 0.823208316229609, 'colsample_bytree': 0.8113112787398798, 'reg_alpha': 5.9675829374953935, 'reg_lambda': 0.802236679594373}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 07:08:29,467] Trial 27 finished with value: 0.4812444545151041 and parameters: {'n_estimators': 599, 'learning_rate': 0.08680070352041538, 'max_depth': 12, 'num_leaves': 128, 'subsample': 0.850743129747711, 'colsample_bytree': 0.7970408109214632, 'reg_alpha': 6.590169309551887, 'reg_lambda': 7.7349522453551645}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 07:17:16,472] Trial 28 finished with value: 0.4734746102537183 and parameters: {'n_estimators': 735, 'learning_rate': 0.13330920922508455, 'max_depth': 15, 'num_leaves': 112, 'subsample': 0.8745591528932907, 'colsample_bytree': 0.82837367653389, 'reg_alpha': 5.45304519197492, 'reg_lambda': 1.8892148546755645}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 07:23:13,119] Trial 29 finished with value: 0.4823055592411846 and parameters: {'n_estimators': 627, 'learning_rate': 0.18247993249263517, 'max_depth': 10, 'num_leaves': 110, 'subsample': 0.8815683639701644, 'colsample_bytree': 0.8264011808109477, 'reg_alpha': 8.234655571560515, 'reg_lambda': 2.0006838003382694}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 07:33:35,641] Trial 30 finished with value: 0.48297481715574064 and parameters: {'n_estimators': 921, 'learning_rate': 0.0551008756101395, 'max_depth': 11, 'num_leaves': 111, 'subsample': 0.9337376245454849, 'colsample_bytree': 0.8833986673023739, 'reg_alpha': 7.2058806235772686, 'reg_lambda': 1.6891305256708609}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 07:41:58,070] Trial 31 finished with value: 0.4764860832882321 and parameters: {'n_estimators': 753, 'learning_rate': 0.19726257803909017, 'max_depth': 15, 'num_leaves': 119, 'subsample': 0.8341977797245429, 'colsample_bytree': 0.789331322798847, 'reg_alpha': 5.382168152768837, 'reg_lambda': 0.674088437946387}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 07:50:42,185] Trial 32 finished with value: 0.47400238130857963 and parameters: {'n_estimators': 749, 'learning_rate': 0.13335408922016118, 'max_depth': 15, 'num_leaves': 117, 'subsample': 0.7899528241311801, 'colsample_bytree': 0.7486699002690661, 'reg_alpha': 5.655759705637821, 'reg_lambda': 3.226822508224844}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 07:56:02,874] Trial 33 finished with value: 0.49616433076339284 and parameters: {'n_estimators': 484, 'learning_rate': 0.09185873093590553, 'max_depth': 13, 'num_leaves': 46, 'subsample': 0.885003973142535, 'colsample_bytree': 0.8353163517925993, 'reg_alpha': 4.4847021986502975, 'reg_lambda': 1.739027499485132}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 08:05:52,607] Trial 34 finished with value: 0.4718092117329895 and parameters: {'n_estimators': 850, 'learning_rate': 0.11566277895636991, 'max_depth': 14, 'num_leaves': 128, 'subsample': 0.7995858844198572, 'colsample_bytree': 0.7619476146484435, 'reg_alpha': 6.599727541926992, 'reg_lambda': 0.8831061369226763}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 08:15:45,965] Trial 35 finished with value: 0.47168298823923593 and parameters: {'n_estimators': 854, 'learning_rate': 0.11076410754259298, 'max_depth': 14, 'num_leaves': 128, 'subsample': 0.798570797086975, 'colsample_bytree': 0.7421202018737038, 'reg_alpha': 6.585521655326377, 'reg_lambda': 3.1499201882515857}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 08:25:37,351] Trial 36 finished with value: 0.47186590858068006 and parameters: {'n_estimators': 858, 'learning_rate': 0.10933222039770063, 'max_depth': 14, 'num_leaves': 128, 'subsample': 0.8057584964153558, 'colsample_bytree': 0.7433920126702226, 'reg_alpha': 6.719137344652692, 'reg_lambda': 3.731378593123558}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 08:34:35,209] Trial 37 finished with value: 0.4750026742776387 and parameters: {'n_estimators': 840, 'learning_rate': 0.11228739864572161, 'max_depth': 12, 'num_leaves': 128, 'subsample': 0.7991901948187642, 'colsample_bytree': 0.7311928373922103, 'reg_alpha': 6.688539609092798, 'reg_lambda': 3.8504714589657247}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 08:43:44,863] Trial 38 finished with value: 0.4738311754789319 and parameters: {'n_estimators': 852, 'learning_rate': 0.16217752011912165, 'max_depth': 13, 'num_leaves': 125, 'subsample': 0.8204790607828235, 'colsample_bytree': 0.7644289483798921, 'reg_alpha': 9.338141363031538, 'reg_lambda': 4.22453438784096}. Best is trial 24 with value: 0.47127563251180704.
# [I 2025-04-24 08:54:26,813] Trial 39 finished with value: 0.4712474283015193 and parameters: {'n_estimators': 942, 'learning_rate': 0.10801532916561221, 'max_depth': 14, 'num_leaves': 123, 'subsample': 0.751696709540462, 'colsample_bytree': 0.6742519389432498, 'reg_alpha': 7.684407178941383, 'reg_lambda': 5.769046430587705}. Best is trial 39 with value: 0.4712474283015193.
# [I 2025-04-24 09:01:48,702] Trial 40 finished with value: 0.4986611940966754 and parameters: {'n_estimators': 937, 'learning_rate': 0.0933790423754157, 'max_depth': 12, 'num_leaves': 23, 'subsample': 0.7514472377786977, 'colsample_bytree': 0.6457473500870359, 'reg_alpha': 8.130676134641977, 'reg_lambda': 5.2738203002099855}. Best is trial 39 with value: 0.4712474283015193.
# [I 2025-04-24 09:12:13,019] Trial 41 finished with value: 0.4714513297842347 and parameters: {'n_estimators': 940, 'learning_rate': 0.1100683381955085, 'max_depth': 14, 'num_leaves': 123, 'subsample': 0.8076650858515145, 'colsample_bytree': 0.6806746689697617, 'reg_alpha': 7.675188440303291, 'reg_lambda': 5.7591998824093125}. Best is trial 39 with value: 0.4712474283015193.
# [I 2025-04-24 09:22:30,922] Trial 42 finished with value: 0.47118514811586026 and parameters: {'n_estimators': 934, 'learning_rate': 0.11699607958113328, 'max_depth': 14, 'num_leaves': 118, 'subsample': 0.7558227314226075, 'colsample_bytree': 0.6777364780847842, 'reg_alpha': 8.676226832243197, 'reg_lambda': 5.670452362229987}. Best is trial 42 with value: 0.47118514811586026.
# [I 2025-04-24 09:33:34,926] Trial 43 finished with value: 0.47175080968534766 and parameters: {'n_estimators': 953, 'learning_rate': 0.08379042246104614, 'max_depth': 14, 'num_leaves': 122, 'subsample': 0.7008802026726506, 'colsample_bytree': 0.678645313174988, 'reg_alpha': 8.828677953513466, 'reg_lambda': 7.008197769400107}. Best is trial 42 with value: 0.47118514811586026.
# [I 2025-04-24 09:44:31,240] Trial 44 finished with value: 0.478240791972846 and parameters: {'n_estimators': 935, 'learning_rate': 0.05854278783780545, 'max_depth': 13, 'num_leaves': 114, 'subsample': 0.7520924942993402, 'colsample_bytree': 0.6503183730635945, 'reg_alpha': 7.7502041174592184, 'reg_lambda': 5.652169562916427}. Best is trial 42 with value: 0.47118514811586026.
# [I 2025-04-24 09:50:44,993] Trial 45 finished with value: 0.500984364789016 and parameters: {'n_estimators': 968, 'learning_rate': 0.10275354513868998, 'max_depth': 6, 'num_leaves': 121, 'subsample': 0.7120374583436153, 'colsample_bytree': 0.7102305388718589, 'reg_alpha': 8.814810159223054, 'reg_lambda': 6.8550390289806895}. Best is trial 42 with value: 0.47118514811586026.
# [I 2025-04-24 09:59:43,565] Trial 46 finished with value: 0.4818081488740739 and parameters: {'n_estimators': 994, 'learning_rate': 0.1601475938035367, 'max_depth': 9, 'num_leaves': 108, 'subsample': 0.6512165074109374, 'colsample_bytree': 0.6328153040348604, 'reg_alpha': 9.989498721083034, 'reg_lambda': 5.8138305522442}. Best is trial 42 with value: 0.47118514811586026.
# [I 2025-04-24 10:03:30,953] Trial 47 finished with value: 0.4930970167642136 and parameters: {'n_estimators': 291, 'learning_rate': 0.12085607759602558, 'max_depth': 12, 'num_leaves': 122, 'subsample': 0.7448041014207453, 'colsample_bytree': 0.6699528225849684, 'reg_alpha': 9.26531318448202, 'reg_lambda': 4.83790941999459}. Best is trial 42 with value: 0.47118514811586026.
# [I 2025-04-24 10:13:14,171] Trial 48 finished with value: 0.48768000368153974 and parameters: {'n_estimators': 790, 'learning_rate': 0.04701114140136985, 'max_depth': 14, 'num_leaves': 81, 'subsample': 0.6697562593082195, 'colsample_bytree': 0.6936794978794235, 'reg_alpha': 7.648050058357246, 'reg_lambda': 7.132967371508143}. Best is trial 42 with value: 0.47118514811586026.
# [I 2025-04-24 10:23:10,387] Trial 49 finished with value: 0.47684378968501107 and parameters: {'n_estimators': 917, 'learning_rate': 0.08192366830432808, 'max_depth': 13, 'num_leaves': 93, 'subsample': 0.8178117394362344, 'colsample_bytree': 0.7283900417225615, 'reg_alpha': 8.420549959092801, 'reg_lambda': 5.4991417746606315}. Best is trial 42 with value: 0.47118514811586026.
# [I 2025-04-24 10:31:57,554] Trial 50 finished with value: 0.47383340707927785 and parameters: {'n_estimators': 811, 'learning_rate': 0.14814450457454212, 'max_depth': 14, 'num_leaves': 114, 'subsample': 0.7255063907025744, 'colsample_bytree': 0.7253728104024482, 'reg_alpha': 6.125500355079585, 'reg_lambda': 6.29652620250169}. Best is trial 42 with value: 0.47118514811586026.
# [I 2025-04-24 10:42:47,699] Trial 51 finished with value: 0.47249956953243294 and parameters: {'n_estimators': 949, 'learning_rate': 0.08349936584029283, 'max_depth': 14, 'num_leaves': 124, 'subsample': 0.7010279570900576, 'colsample_bytree': 0.6645022636818882, 'reg_alpha': 8.710883211231508, 'reg_lambda': 7.999051831926186}. Best is trial 42 with value: 0.47118514811586026.
# [I 2025-04-24 10:53:06,297] Trial 52 finished with value: 0.4722957924160719 and parameters: {'n_estimators': 958, 'learning_rate': 0.09966782205663502, 'max_depth': 13, 'num_leaves': 122, 'subsample': 0.7638222061686428, 'colsample_bytree': 0.6753131803644286, 'reg_alpha': 9.08460506096375, 'reg_lambda': 7.023003467842894}. Best is trial 42 with value: 0.47118514811586026.
# [I 2025-04-24 11:06:33,793] Trial 53 finished with value: 0.4795449664091145 and parameters: {'n_estimators': 882, 'learning_rate': 0.06089172151456325, 'max_depth': 14, 'num_leaves': 106, 'subsample': 0.6161444376613322, 'colsample_bytree': 0.6028331953745003, 'reg_alpha': 7.645643125909465, 'reg_lambda': 6.45934517288278}. Best is trial 42 with value: 0.47118514811586026.
# [I 2025-04-24 11:22:03,485] Trial 54 finished with value: 0.4697578099388964 and parameters: {'n_estimators': 986, 'learning_rate': 0.12427334451896234, 'max_depth': 15, 'num_leaves': 120, 'subsample': 0.7878633822596327, 'colsample_bytree': 0.6849833789677743, 'reg_alpha': 6.950905962436478, 'reg_lambda': 4.359145597341335}. Best is trial 54 with value: 0.4697578099388964.
# [I 2025-04-24 11:36:17,167] Trial 55 finished with value: 0.47722945463904726 and parameters: {'n_estimators': 995, 'learning_rate': 0.12701225777900804, 'max_depth': 15, 'num_leaves': 67, 'subsample': 0.7869266436049085, 'colsample_bytree': 0.6264234863312226, 'reg_alpha': 6.977455252064754, 'reg_lambda': 4.331973012049721}. Best is trial 54 with value: 0.4697578099388964.
# [I 2025-04-24 11:51:33,697] Trial 56 finished with value: 0.4717081244508084 and parameters: {'n_estimators': 878, 'learning_rate': 0.10137889916523268, 'max_depth': 15, 'num_leaves': 116, 'subsample': 0.86671805040526, 'colsample_bytree': 0.7021438437366109, 'reg_alpha': 5.932508162062116, 'reg_lambda': 4.986594084270429}. Best is trial 54 with value: 0.4697578099388964.
# [I 2025-04-24 12:04:46,745] Trial 57 finished with value: 0.47278987133210876 and parameters: {'n_estimators': 919, 'learning_rate': 0.1748212650873997, 'max_depth': 14, 'num_leaves': 124, 'subsample': 0.7271098785576101, 'colsample_bytree': 0.7758148830526133, 'reg_alpha': 7.797060854986517, 'reg_lambda': 2.95991065659711}. Best is trial 54 with value: 0.4697578099388964.
# [I 2025-04-24 12:19:22,978] Trial 58 finished with value: 0.47404516942748903 and parameters: {'n_estimators': 817, 'learning_rate': 0.15025281255958373, 'max_depth': 15, 'num_leaves': 119, 'subsample': 0.835325677408901, 'colsample_bytree': 0.6904951835394894, 'reg_alpha': 6.2716814554717475, 'reg_lambda': 5.217899616495282}. Best is trial 54 with value: 0.4697578099388964.
# [I 2025-04-24 12:40:34,412] Trial 59 finished with value: 0.4730804378790326 and parameters: {'n_estimators': 999, 'learning_rate': 0.12141166365400007, 'max_depth': 13, 'num_leaves': 103, 'subsample': 0.7596660495618033, 'colsample_bytree': 0.720015719929196, 'reg_alpha': 7.099517810854703, 'reg_lambda': 4.503117391564886}. Best is trial 54 with value: 0.4697578099388964.
# [I 2025-04-24 12:55:12,240] Trial 60 finished with value: 0.4960401651465951 and parameters: {'n_estimators': 670, 'learning_rate': 0.09280245912344921, 'max_depth': 8, 'num_leaves': 108, 'subsample': 0.7865421779033376, 'colsample_bytree': 0.6371464599706611, 'reg_alpha': 8.025467423324525, 'reg_lambda': 5.964191647850571}. Best is trial 54 with value: 0.4697578099388964.
# [I 2025-04-24 13:14:51,306] Trial 61 finished with value: 0.47175826742819055 and parameters: {'n_estimators': 882, 'learning_rate': 0.10512025704153204, 'max_depth': 15, 'num_leaves': 115, 'subsample': 0.8118724688296894, 'colsample_bytree': 0.7053409483261704, 'reg_alpha': 5.754712650482204, 'reg_lambda': 4.961638777256894}. Best is trial 54 with value: 0.4697578099388964.
# [I 2025-04-24 13:28:27,254] Trial 62 finished with value: 0.47167966491977487 and parameters: {'n_estimators': 913, 'learning_rate': 0.1060551992916613, 'max_depth': 15, 'num_leaves': 115, 'subsample': 0.8647296718629055, 'colsample_bytree': 0.6618252612779709, 'reg_alpha': 7.394300921429592, 'reg_lambda': 4.154471261860731}. Best is trial 54 with value: 0.4697578099388964.
# [I 2025-04-24 13:43:16,057] Trial 63 finished with value: 0.47448022448445043 and parameters: {'n_estimators': 914, 'learning_rate': 0.07590109366737655, 'max_depth': 15, 'num_leaves': 98, 'subsample': 0.8973185055857216, 'colsample_bytree': 0.6640876598282155, 'reg_alpha': 7.309649900604001, 'reg_lambda': 3.9162019742438208}. Best is trial 54 with value: 0.4697578099388964.

# %%
# Mostrar resultados
print("Mejor MAE:", study.best_value)
print("Mejores parámetros:")
for k, v in study.best_params.items():
    print(f"  {k}: {v}")
# Out:
# Mejor MAE: 0.5154400496881063
# Mejores parámetros:
#   n_estimators: 278
#   learning_rate: 0.06413462050486568
#   max_depth: 9
#   num_leaves: 123
#   subsample: 0.9393480665281766
#   colsample_bytree: 0.8178892720846546
#   reg_alpha: 4.327709697928053
#   reg_lambda: 0.8802452369121416

# %%
best_model = LGBMRegressor(**study.best_params)
best_model.fit(X_train_final, y_train)

y_pred = best_model.predict(X_test_final)
# Out:
# c:\Users\paula\anaconda3\envs\py311_env\Lib\site-packages\lightgbm\basic.py:1238: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning("Converting data to scipy sparse matrix.")

# %%
df_submission = pd.DataFrame({
    "review_id": df_test["review_id"],
    "stars": y_pred
})
df_submission.to_csv("predictions_contenido/prediction_tfidf_lightgbm_optuna2.csv", index=False)
